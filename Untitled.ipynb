# %%
# import libraries 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

import openpyxl

# %%
# data import 
CustomerAddress = pd.read_csv('CustomerAddress1.csv',header = 1)
CustomerAddress.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
NewCustomerList= pd.read_csv('NewCustomerList.csv',header = 1)
NewCustomerList.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#           DOB                   job_title job_industry_category  \
# 0  1957-07-12             General Manager         Manufacturing
# 1  1970-03-22         Structural Engineer              Property
# 2  1974-08-28      Senior Cost Accountant    Financial Services
# 3  1979-01-28  Account Representative III         Manufacturing
# 4  1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0      Mass Customer                  N      Yes  ...    QLD  Australia
# ...

# %%
Transactions= pd.read_csv('Transactions.csv',header = 1)
Transactions.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       02/25/2017           0.0
# 1               2           3         3120       05/21/2017           1.0
# 2               3          37          402       10/16/2017           0.0
# 3               4          88         3135       08/31/2017           0.0
# 4               5          78          787       10/01/2017           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
Customer_Demographic = pd.read_csv('CustomerDemographic.csv',header = 1)
Customer_Demographic.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0          1.0         Laraine  Medendorp       F
# 1          2.0             Eli    Bockman    Male
# 2          3.0           Arlin     Dearle    Male
# 3          4.0          Talbot        NaN    Male
# 4          5.0  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases         DOB               job_title  \
# 0                                 93.0  12-10-1953     Executive Secretary
# 1                                 81.0  16-12-1980  Administrative Officer
# 2                                 61.0  20-01-1954      Recruiting Manager
# 3                                 33.0  03-10-1961                     NaN
# 4                                 56.0  13-05-1977           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator Unnamed: 10  \
# 0                Health      Mass Customer                  N         Yes
# ...

# %%
# customer address
CustomerAddress.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
CustomerAddress.isnull().sum()
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %%
CustomerAddress.describe()
# Out:
#        customer_id     postcode  property_valuation
# count  3999.000000  3999.000000         3999.000000
# mean   2003.987997  2985.755939            7.514379
# std    1154.576912   844.878364            2.824663
# min       1.000000  2000.000000            1.000000
# 25%    1004.500000  2200.000000            6.000000
# 50%    2004.000000  2768.000000            8.000000
# 75%    3003.500000  3750.000000           10.000000
# max    4003.000000  4883.000000           12.000000

# %%
CustomerAddress.shape
# Out:
# (3999, 6)

# %%
CustomerAddress.nunique()
# Out:
# customer_id           3999
# address               3996
# postcode               873
# state                    5
# country                  1
# property_valuation      12
# dtype: int64

# %%
CustomerAddress.drop_duplicates()
# Out:
#       customer_id                    address  postcode            state  \
# 0               1         060 Morning Avenue      2016  New South Wales
# 1               2        6 Meadow Vale Court      2153  New South Wales
# 2               4         0 Holy Cross Court      4211              QLD
# 3               5        17979 Del Mar Point      2448  New South Wales
# 4               6           9 Oakridge Court      3216              VIC
# ...           ...                        ...       ...              ...
# 3994         3999            1482 Hauk Trail      3064              VIC
# 3995         4000  57042 Village Green Point      4511              QLD
# 3996         4001     87 Crescent Oaks Alley      2756              NSW
# 3997         4002           8194 Lien Street      4032              QLD
# 3998         4003            320 Acker Drive      2251              NSW
#
#         country  property_valuation
# 0     Australia                  10
# ...

# %%
#  New Customer List
NewCustomerList.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#           DOB                   job_title job_industry_category  \
# 0  1957-07-12             General Manager         Manufacturing
# 1  1970-03-22         Structural Engineer              Property
# 2  1974-08-28      Senior Cost Accountant    Financial Services
# 3  1979-01-28  Account Representative III         Manufacturing
# 4  1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0      Mass Customer                  N      Yes  ...    QLD  Australia
# ...

# %%
NewCustomerList.describe()
# Out:
#        past_3_years_bike_related_purchases       tenure     postcode  \
# count                          1000.000000  1000.000000  1000.000000
# mean                             49.836000    11.388000  3019.227000
# std                              27.796686     5.037145   848.895767
# min                               0.000000     0.000000  2000.000000
# 25%                              26.750000     7.000000  2209.000000
# 50%                              51.000000    11.000000  2800.000000
# 75%                              72.000000    15.000000  3845.500000
# max                              99.000000    22.000000  4879.000000
#
#        property_valuation  Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# count         1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean             7.397000     0.755690     0.848098     0.954856     0.880731
# std              2.758804     0.201136     0.242622     0.294823     0.278119
# ...

# %%
NewCustomerList.shape
# Out:
# (1000, 23)

# %%
NewCustomerList.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Unnamed: 16                              0
# Unnamed: 17                              0
# Unnamed: 18                              0
# Unnamed: 19                              0
# Unnamed: 20                              0
# Rank                                     0
# ...

# %%
NewCustomerList.drop_duplicates()
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#             DOB                     job_title job_industry_category  \
# ...

# %%
NewCustomerList['last_name'].value_counts(normalize=True)
# Out:
# Sturch         0.00206
# Eade           0.00206
# Hallt          0.00206
# Sissel         0.00206
# Borsi          0.00206
#                 ...
# Densie         0.00103
# Kedie          0.00103
# Yakubov        0.00103
# MacConnulty    0.00103
# Mandy          0.00103
# Name: last_name, Length: 961, dtype: float64

# %%
# Removing the null values (NewCustomerList)
NewCustomerList['last_name'].isnull().sum()
# drop all the null values

NewCustomerList = NewCustomerList[~NewCustomerList.last_name.isnull()]

NewCustomerList.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#           DOB                   job_title job_industry_category  \
# 0  1957-07-12             General Manager         Manufacturing
# 1  1970-03-22         Structural Engineer              Property
# 2  1974-08-28      Senior Cost Accountant    Financial Services
# 3  1979-01-28  Account Representative III         Manufacturing
# 4  1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0      Mass Customer                  N      Yes  ...    QLD  Australia
# ...

# %%
NewCustomerList.isnull().sum()
# Out:
# first_name                               0
# last_name                                0
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              103
# job_industry_category                  159
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Unnamed: 16                              0
# Unnamed: 17                              0
# Unnamed: 18                              0
# Unnamed: 19                              0
# Unnamed: 20                              0
# Rank                                     0
# ...

# %%
# drop all the null values for the DOB

NewCustomerList = NewCustomerList[~NewCustomerList.DOB.isnull()]
NewCustomerList.isnull().sum()
# Out:
# first_name                               0
# last_name                                0
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                      0
# job_title                              102
# job_industry_category                  159
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Unnamed: 16                              0
# Unnamed: 17                              0
# Unnamed: 18                              0
# Unnamed: 19                              0
# Unnamed: 20                              0
# Rank                                     0
# ...

# %%
# job title
NewCustomerList.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#           DOB                   job_title job_industry_category  \
# 0  1957-07-12             General Manager         Manufacturing
# 1  1970-03-22         Structural Engineer              Property
# 2  1974-08-28      Senior Cost Accountant    Financial Services
# 3  1979-01-28  Account Representative III         Manufacturing
# 4  1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0      Mass Customer                  N      Yes  ...    QLD  Australia
# ...

# %%
NewCustomerList['job_title'].value_counts(normalize=True)
# Out:
# Associate Professor           0.016432
# Software Consultant           0.016432
# Environmental Tech            0.016432
# Cost Accountant               0.014085
# Chief Design Engineer         0.014085
#                                 ...
# Software Test Engineer III    0.001174
# Staff Accountant I            0.001174
# Developer II                  0.001174
# Accounting Assistant II       0.001174
# Administrative Officer        0.001174
# Name: job_title, Length: 183, dtype: float64

# %%
##   drop the job_title with null values
NewCustomerList=NewCustomerList[~NewCustomerList.job_title.isnull()]
NewCustomerList.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#           DOB                   job_title job_industry_category  \
# 0  1957-07-12             General Manager         Manufacturing
# 1  1970-03-22         Structural Engineer              Property
# 2  1974-08-28      Senior Cost Accountant    Financial Services
# 3  1979-01-28  Account Representative III         Manufacturing
# 4  1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0      Mass Customer                  N      Yes  ...    QLD  Australia
# ...

# %%
# job_industry_category
NewCustomerList['job_industry_category'].value_counts(normalize = True)
# Out:
# Financial Services    0.254545
# Manufacturing         0.239161
# Health                0.188811
# Retail                0.102098
# Property              0.068531
# Entertainment         0.044755
# IT                    0.040559
# Argiculture           0.032168
# Telecommunications    0.029371
# Name: job_industry_category, dtype: float64

# %%
# drop the null values 
NewCustomerList['job_industry_category'].fillna(value = 'Financial Services',inplace=True)

# replacing all the values with the mode values of the column

# %%
NewCustomerList.isnull().sum()
# Out:
# first_name                             0
# last_name                              0
# gender                                 0
# past_3_years_bike_related_purchases    0
# DOB                                    0
# job_title                              0
# job_industry_category                  0
# wealth_segment                         0
# deceased_indicator                     0
# owns_car                               0
# tenure                                 0
# address                                0
# postcode                               0
# state                                  0
# country                                0
# property_valuation                     0
# Unnamed: 16                            0
# Unnamed: 17                            0
# Unnamed: 18                            0
# Unnamed: 19                            0
# Unnamed: 20                            0
# Rank                                   0
# Value                                  0
# ...

# %%
# Transactions 
Transactions.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       02/25/2017           0.0
# 1               2           3         3120       05/21/2017           1.0
# 2               3          37          402       10/16/2017           0.0
# 3               4          88         3135       08/31/2017           0.0
# 4               5          78          787       10/01/2017           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
Transactions = Transactions.drop_duplicates()

Transactions.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       02/25/2017           0.0
# 1               2           3         3120       05/21/2017           1.0
# 2               3          37          402       10/16/2017           0.0
# 3               4          88         3135       08/31/2017           0.0
# 4               5          78          787       10/01/2017           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
Transactions = Transactions.drop('transaction_id',axis=1)
Transactions.head()
# Out:
#    product_id  customer_id transaction_date  online_order order_status  \
# 0           2         2950       02/25/2017           0.0     Approved
# 1           3         3120       05/21/2017           1.0     Approved
# 2          37          402       10/16/2017           0.0     Approved
# 3          88         3135       08/31/2017           0.0     Approved
# 4          78          787       10/01/2017           1.0     Approved
#
#             brand product_line product_class product_size  list_price  \
# 0           Solex     Standard        medium       medium       71.49
# 1   Trek Bicycles     Standard        medium        large     2091.47
# 2      OHM Cycles     Standard           low       medium     1793.43
# 3  Norco Bicycles     Standard        medium       medium     1198.46
# 4  Giant Bicycles     Standard        medium        large     1765.30
#
#    standard_cost  product_first_sold_date
# 0          53.62                  41245.0
# ...

# %%
Transactions.describe()
# Out:
#         product_id   customer_id  online_order    list_price  standard_cost  \
# count  20000.00000  20000.000000  19640.000000  20000.000000   19803.000000
# mean      45.36465   1738.246050      0.500458   1107.829449     556.046951
# std       30.75359   1011.951046      0.500013    582.825242     405.955660
# min        0.00000      1.000000      0.000000     12.010000       7.210000
# 25%       18.00000    857.750000      0.000000    575.270000     215.140000
# 50%       44.00000   1736.000000      1.000000   1163.890000     507.580000
# 75%       72.00000   2613.000000      1.000000   1635.300000     795.100000
# max      100.00000   5034.000000      1.000000   2091.470000    1759.850000
#
#        product_first_sold_date
# count             19803.000000
# mean              38199.776549
# std                2875.201110
# min               33259.000000
# 25%               35667.000000
# 50%               38216.000000
# 75%               40672.000000
# ...

# %%
Transactions.shape
# Out:
# (20000, 12)

# %%
Transactions = Transactions[~Transactions.online_order.isnull()]

# %%
Transactions.isnull().sum()
# Out:
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order                 0
# order_status                 0
# brand                      195
# product_line               195
# product_class              195
# product_size               195
# list_price                   0
# standard_cost              195
# product_first_sold_date    195
# dtype: int64

# %%
Transactions['brand'].value_counts(normalize =True)
# Out:
# Solex             0.214400
# WeareA2B          0.166881
# Giant Bicycles    0.166830
# OHM Cycles        0.153921
# Trek Bicycles     0.150733
# Norco Bicycles    0.147236
# Name: brand, dtype: float64

# %%
Transactions['brand'].fillna('Solex',inplace = True)
Transactions['product_line'].fillna('Standard',inplace = True)
Transactions['product_class'].fillna('medium',inplace =True)
Transactions['product_size'].fillna('medium',inplace = True)

# %%
# drop the columns which are not useful
Transactions=Transactions.drop('product_first_sold_date',axis =1)

# %%
Transactions.isnull().sum()
# Out:
# product_id            0
# customer_id           0
# transaction_date      0
# online_order          0
# order_status          0
# brand                 0
# product_line          0
# product_class         0
# product_size          0
# list_price            0
# standard_cost       195
# dtype: int64

# %%
Transactions['standard_cost'].quantile([0,0.25,0.50,0.75,0.90,0.95,0.99])
# Out:
# 0.00       7.21
# 0.25     215.14
# 0.50     507.58
# 0.75     795.10
# 0.90    1105.75
# 0.95    1479.11
# 0.99    1610.90
# Name: standard_cost, dtype: float64

# %%
Transactions=Transactions[~Transactions.standard_cost.isnull()]

# %%
Transactions.isnull().sum()
# Out:
# product_id          0
# customer_id         0
# transaction_date    0
# online_order        0
# order_status        0
# brand               0
# product_line        0
# product_class       0
# product_size        0
# list_price          0
# standard_cost       0
# dtype: int64

# %%
Transactions.isnull().sum()
# Out:
# product_id          0
# customer_id         0
# transaction_date    0
# online_order        0
# order_status        0
# brand               0
# product_line        0
# product_class       0
# product_size        0
# list_price          0
# standard_cost       0
# dtype: int64

# %%
Transactions.dtypes
# Out:
# product_id            int64
# customer_id           int64
# transaction_date     object
# online_order        float64
# order_status         object
# brand                object
# product_line         object
# product_class        object
# product_size         object
# list_price          float64
# standard_cost       float64
# dtype: object

# %%
Transactions['transaction_date'] = pd.to_datetime(Transactions['transaction_date'])

# %%
Transactions.dtypes
# Out:
# product_id                   int64
# customer_id                  int64
# transaction_date    datetime64[ns]
# online_order               float64
# order_status                object
# brand                       object
# product_line                object
# product_class               object
# product_size                object
# list_price                 float64
# standard_cost              float64
# dtype: object

# %%
Transactions['transaction_date'] = Transactions['transaction_date'].dt.month

# %%
Transactions['month']=Transactions['transaction_date']

# %%
Transactions.head()
# Out:
#    product_id  customer_id  transaction_date  online_order order_status  \
# 0           2         2950                 2           0.0     Approved
# 1           3         3120                 5           1.0     Approved
# 2          37          402                10           0.0     Approved
# 3          88         3135                 8           0.0     Approved
# 4          78          787                10           1.0     Approved
#
#             brand product_line product_class product_size  list_price  \
# 0           Solex     Standard        medium       medium       71.49
# 1   Trek Bicycles     Standard        medium        large     2091.47
# 2      OHM Cycles     Standard           low       medium     1793.43
# 3  Norco Bicycles     Standard        medium       medium     1198.46
# 4  Giant Bicycles     Standard        medium        large     1765.30
#
#    standard_cost  month
# 0          53.62      2
# 1         388.92      5
# 2         248.82     10
# ...

# %% [markdown]
# # Customer Demographic

# %%
# loading
Customer_demographic = pd.read_csv('CustomerDemographic.csv',header=1)

# %%
Customer_demographic.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0          1.0         Laraine  Medendorp       F
# 1          2.0             Eli    Bockman    Male
# 2          3.0           Arlin     Dearle    Male
# 3          4.0          Talbot        NaN    Male
# 4          5.0  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases         DOB               job_title  \
# 0                                 93.0  12-10-1953     Executive Secretary
# 1                                 81.0  16-12-1980  Administrative Officer
# 2                                 61.0  20-01-1954      Recruiting Manager
# 3                                 33.0  03-10-1961                     NaN
# 4                                 56.0  13-05-1977           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator Unnamed: 10  \
# 0                Health      Mass Customer                  N         Yes
# ...

# %%
Customer_demographic.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'Unnamed: 10', 'owns_car', 'tenure'],
#       dtype='object')

# %%
Customer_demographic.shape
# Out:
# (4200, 13)

# %%
Customer_demographic.isnull().sum()
# Out:
# customer_id                            200
# first_name                             200
# last_name                              325
# gender                                 200
# past_3_years_bike_related_purchases    200
# DOB                                    287
# job_title                              706
# job_industry_category                  856
# wealth_segment                         200
# deceased_indicator                     200
# Unnamed: 10                              0
# owns_car                               201
# tenure                                 287
# dtype: int64

# %%
Customer_demographic.dtypes
# Out:
# customer_id                            float64
# first_name                              object
# last_name                               object
# gender                                  object
# past_3_years_bike_related_purchases    float64
# DOB                                     object
# job_title                               object
# job_industry_category                   object
# wealth_segment                          object
# deceased_indicator                      object
# Unnamed: 10                             object
# owns_car                                object
# tenure                                 float64
# dtype: object

# %%
Customer_demographic.drop_duplicates().head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0          1.0         Laraine  Medendorp       F
# 1          2.0             Eli    Bockman    Male
# 2          3.0           Arlin     Dearle    Male
# 3          4.0          Talbot        NaN    Male
# 4          5.0  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases         DOB               job_title  \
# 0                                 93.0  12-10-1953     Executive Secretary
# 1                                 81.0  16-12-1980  Administrative Officer
# 2                                 61.0  20-01-1954      Recruiting Manager
# 3                                 33.0  03-10-1961                     NaN
# 4                                 56.0  13-05-1977           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator Unnamed: 10  \
# 0                Health      Mass Customer                  N         Yes
# ...

# %%
Customer_demographic.shape
# Out:
# (4200, 13)

# %%
# dropping the columns
Customer_demographic.drop(['customer_id'],inplace = True,axis =1)

# %%
Customer_demographic.drop(['Unnamed: 10'],axis =1,inplace = True)

# %%
Customer_demographic.isnull().sum()
# Out:
# first_name                             200
# last_name                              325
# gender                                 200
# past_3_years_bike_related_purchases    200
# DOB                                    287
# job_title                              706
# job_industry_category                  856
# wealth_segment                         200
# deceased_indicator                     200
# owns_car                               201
# tenure                                 287
# dtype: int64

# %%
# dropping the null values 
Customer_demographic = Customer_demographic[~Customer_demographic.first_name.isnull()]
Customer_demographic = Customer_demographic[~Customer_demographic.last_name.isnull()]
Customer_demographic = Customer_demographic[~Customer_demographic.owns_car.isna()]

# %%
Customer_demographic.gender.value_counts()
# Out:
# Female    1980
# Male      1808
# U           84
# Femal        1
# M            1
# Name: gender, dtype: int64

# %%
Customer_demographic['gender'].replace('Femal','Female',inplace = True)
Customer_demographic['gender'].replace('F','Female',inplace = True)
Customer_demographic['gender'].replace('M','Male',inplace = True)

# %%
Customer_demographic['gender']=Customer_demographic[~Customer_demographic['gender'].isna()]

# %%
Customer_demographic.isnull().sum()
# Out:
# first_name                               0
# last_name                                0
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     83
# job_title                              490
# job_industry_category                  631
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                  83
# dtype: int64

# %%
Customer_demographic.reset_index(inplace = True)

# %%
Customer_demographic['DOB'] = Customer_demographic[~Customer_demographic.DOB.isnull()]

# %%
Customer_demographic['DOB'] = pd.to_datetime(Customer_Demographic['DOB'])

# %%
Customer_demographic['year'] = Customer_demographic['DOB'].dt.year

# %%
Customer_demographic.head()
# Out:
#    index      first_name  last_name          gender  \
# 0      1             Eli    Bockman             Eli
# 1      2           Arlin     Dearle           Arlin
# 2      4  Sheila-kathryn     Calton  Sheila-kathryn
# 3      5            Curr  Duckhouse            Curr
# 4      6            Fina     Merali            Fina
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                 81.0 1953-12-10  Administrative Officer
# 1                                 61.0 1980-12-16      Recruiting Manager
# 2                                 56.0 1954-01-20           Senior Editor
# 3                                 35.0 1961-03-10                     NaN
# 4                                  6.0 1977-05-13                     NaN
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  \
# 0    Financial Services      Mass Customer                  N      Yes
# ...

# %%
Customer_demographic['past_3_years_bike_related_purchases'] = Customer_demographic['past_3_years_bike_related_purchases'].astype('int')

# %%
Customer_demographic['job_title'].value_counts(normalize = True)
# Out:
# Business Systems Development Analyst    0.013002
# Social Worker                           0.012707
# Tax Accountant                          0.012707
# Internal Auditor                        0.012411
# Recruiting Manager                      0.012116
#                                           ...
# Health Coach I                          0.000887
# Research Assistant III                  0.000887
# Database Administrator I                0.000887
# Health Coach III                        0.000887
# Developer I                             0.000296
# Name: job_title, Length: 195, dtype: float64

# %%
Customer_demographic = Customer_demographic[~Customer_demographic.job_title.isna()]

# %%
Customer_demographic['job_industry_category'].value_counts()
# Out:
# Manufacturing         673
# Financial Services    668
# Health                533
# Retail                297
# Property              229
# IT                    183
# Entertainment         116
# Argiculture            97
# Telecommunications     57
# Name: job_industry_category, dtype: int64

# %%
Customer_demographic = Customer_demographic[~Customer_demographic.job_industry_category.isna()]

# %%
Customer_demographic = Customer_demographic[~Customer_demographic.tenure.isnull()]

# %%
# data types
Customer_demographic['tenure'] = Customer_demographic['tenure'].astype('int')

# %%
Customer_demographic.dtypes
# Out:
# index                                           int64
# first_name                                     object
# last_name                                      object
# gender                                         object
# past_3_years_bike_related_purchases             int32
# DOB                                    datetime64[ns]
# job_title                                      object
# job_industry_category                          object
# wealth_segment                                 object
# deceased_indicator                             object
# owns_car                                       object
# tenure                                          int32
# year                                          float64
# dtype: object

# %%
Customer_demographic = Customer_demographic[~Customer_demographic['year'].isna()]

# %%
Customer_demographic.isnull().sum()
# Out:
# index                                  0
# first_name                             0
# last_name                              0
# gender                                 0
# past_3_years_bike_related_purchases    0
# DOB                                    0
# job_title                              0
# job_industry_category                  0
# wealth_segment                         0
# deceased_indicator                     0
# owns_car                               0
# tenure                                 0
# year                                   0
# dtype: int64

# %% [markdown]
# ##

# %% [markdown]
# so, it is end of the task 1 in the KPMG intership program

# %% [markdown]
# ## Data visualization

# %%
# graphs 
Transactions.head()
# Out:
#    product_id  customer_id  transaction_date  online_order order_status  \
# 0           2         2950                 2           0.0     Approved
# 1           3         3120                 5           1.0     Approved
# 2          37          402                10           0.0     Approved
# 3          88         3135                 8           0.0     Approved
# 4          78          787                10           1.0     Approved
#
#             brand product_line product_class product_size  list_price  \
# 0           Solex     Standard        medium       medium       71.49
# 1   Trek Bicycles     Standard        medium        large     2091.47
# 2      OHM Cycles     Standard           low       medium     1793.43
# 3  Norco Bicycles     Standard        medium       medium     1198.46
# 4  Giant Bicycles     Standard        medium        large     1765.30
#
#    standard_cost  month
# 0          53.62      2
# 1         388.92      5
# 2         248.82     10
# ...

# %%
# bar 
Transactions.groupby(['brand'])['standard_cost'].median().plot.bar()
# Out:
# <AxesSubplot:xlabel='brand'>

# %%
# line chart 
r_1 = Transactions.groupby(['month'])['standard_cost'].median()
plt.plot(r_1,color = 'g',linewidth= 3,linestyle = '--',marker = '.',label = 'standard-cost')
plt.legend()
plt.title('standard_cost over the year',fontdict = {'fontsize' : 19,'color' : 'green'})
plt.xlabel('months',)
plt.ylabel('standard_cost')
plt.tight_layout()
plt.style.use('ggplot')
plt.grid(True)
plt.show()

# %%
# hist
plt.hist(Transactions['product_line'],bins = 20,edgecolor = 'red',color = 'green')
plt.show()

# %%
sns.jointplot(Transactions['list_price'],Transactions['standard_cost'],kind = 'reg')
# Out:
# C:\Users\ved prakash shukla\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
Transactions.groupby(['order_status'])['online_order'].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='order_status'>

# %%
# heat
res = pd.pivot_table(data = Transactions, index = 'brand',columns = 'product_size',values = 'standard_cost',aggfunc = lambda x:np.quantile(x,0.2))
res
# Out:
# product_size     large  medium    small
# brand
# Giant Bicycles  582.48  211.37   525.33
# Norco Bicycles  464.72  290.41   521.94
# OHM Cycles        7.21  101.58  1610.90
# Solex           380.74   75.26  1516.13
# Trek Bicycles   388.92  215.03  1234.29
# WeareA2B         57.74  108.76   131.92

# %%
res.plot(kind = 'bar',stacked = True ,figsize = [10,6] )
plt.show()

# %%
Customer_demographic.head()
# Out:
#    index first_name last_name    gender  past_3_years_bike_related_purchases  \
# 0      1        Eli   Bockman       Eli                                   81
# 1      2      Arlin    Dearle     Arlin                                   61
# 6      8       Mala      Lind      Mala                                   97
# 7      9   Fiorenze   Birdall  Fiorenze                                   49
# 9     11    Sawyere  Flattman   Sawyere                                   58
#
#          DOB                             job_title job_industry_category  \
# 0 1953-12-10                Administrative Officer    Financial Services
# 1 1980-12-16                    Recruiting Manager              Property
# 6 1976-02-23  Business Systems Development Analyst           Argiculture
# 7 1962-03-30               Senior Quality Engineer    Financial Services
# 9 1988-11-10                Nuclear Power Engineer         Manufacturing
#
# ...

# %%
# adding the two columns 
Customer_demographic['Name'] = Customer_demographic['first_name']+" "+ Customer_demographic['last_name']

# %%
Customer_demographic.drop(['first_name','last_name'],inplace = True,axis = 1)

# %%
Customer_demographic.head()
# Out:
#    index    gender  past_3_years_bike_related_purchases        DOB  \
# 0      1       Eli                                   81 1953-12-10
# 1      2     Arlin                                   61 1980-12-16
# 6      8      Mala                                   97 1976-02-23
# 7      9  Fiorenze                                   49 1962-03-30
# 9     11   Sawyere                                   58 1988-11-10
#
#                               job_title job_industry_category  \
# 0                Administrative Officer    Financial Services
# 1                    Recruiting Manager              Property
# 6  Business Systems Development Analyst           Argiculture
# 7               Senior Quality Engineer    Financial Services
# 9                Nuclear Power Engineer         Manufacturing
#
#       wealth_segment deceased_indicator owns_car  tenure    year  \
# 0      Mass Customer                  N      Yes      16  1953.0
# ...

# %%
Customer_demographic.drop(['gender'],inplace = True , axis =1)

# %%
Customer_demographic.head()
# Out:
#    index  past_3_years_bike_related_purchases        DOB  \
# 0      1                                   81 1953-12-10
# 1      2                                   61 1980-12-16
# 6      8                                   97 1976-02-23
# 7      9                                   49 1962-03-30
# 9     11                                   58 1988-11-10
#
#                               job_title job_industry_category  \
# 0                Administrative Officer    Financial Services
# 1                    Recruiting Manager              Property
# 6  Business Systems Development Analyst           Argiculture
# 7               Senior Quality Engineer    Financial Services
# 9                Nuclear Power Engineer         Manufacturing
#
#       wealth_segment deceased_indicator owns_car  tenure    year  \
# 0      Mass Customer                  N      Yes      16  1953.0
# 1      Mass Customer                  N      Yes      15  1980.0
# ...

# %%
Customer_demographic.groupby(['job_title'])['past_3_years_bike_related_purchases'].sum().head(15).plot.bar()
# Out:
# <AxesSubplot:xlabel='job_title'>

# %%
Customer_demographic['age_group'] = pd.qcut(Customer_demographic['year'],[0,0.2,0.4,0.6,0.8,1],['lower_group','middle_group','upper_middle','above_50','senior_citizen'])

# %%
Customer_demographic.groupby(['age_group'])['past_3_years_bike_related_purchases'].sum().plot.barh()

plt.title('Age_group purchases in 3 year ',color = 'green')
# Out:
# Text(0.5, 1.0, 'Age_group purchases in 3 year ')

# %%
Customer_demographic['owns_car'] = Customer_demographic['owns_car'].replace('Yes',1)
Customer_demographic['owns_car'] = Customer_demographic['owns_car'].replace('No',0)

# %%
Customer_demographic.head()
# Out:
#    index  past_3_years_bike_related_purchases        DOB  \
# 0      1                                   81 1953-12-10
# 1      2                                   61 1980-12-16
# 6      8                                   97 1976-02-23
# 7      9                                   49 1962-03-30
# 9     11                                   58 1988-11-10
#
#                               job_title job_industry_category  \
# 0                Administrative Officer    Financial Services
# 1                    Recruiting Manager              Property
# 6  Business Systems Development Analyst           Argiculture
# 7               Senior Quality Engineer    Financial Services
# 9                Nuclear Power Engineer         Manufacturing
#
#       wealth_segment deceased_indicator  owns_car  tenure    year  \
# 0      Mass Customer                  N         1      16  1953.0
# 1      Mass Customer                  N         1      15  1980.0
# ...

# %%
plt.figure(figsize = [9,9],)
r = Customer_demographic.groupby(['job_industry_category'])['owns_car'].sum().plot.bar()
r.set_label('job')
plt.title('owner of cars',fontsize = 20,color = 'red')
plt.ylabel('cars')
# Out:
# Text(0, 0.5, 'cars')

# %%
res_2 = pd.pivot_table(data = Customer_demographic,index = 'job_industry_category',columns = 'age_group',values = 'owns_car',aggfunc = sum)

# %%
res_2.plot( kind ='bar',stacked = True,figsize = [12,10])
# Out:
# <AxesSubplot:xlabel='job_industry_category'>

# %%
Customer_demographic['wealth_segment'].value_counts()
# Out:
# Mass Customer        1363
# High Net Worth        696
# Affluent Customer     668
# Name: wealth_segment, dtype: int64

# %%
Customer_demographic['deceased_indicator'] = Customer_demographic['deceased_indicator'].replace('N',0)
Customer_demographic['deceased_indicator'] = Customer_demographic['deceased_indicator'].replace('Y',1)

# %%
Customer_demographic.groupby(['job_industry_category'])['deceased_indicator'].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='job_industry_category'>
